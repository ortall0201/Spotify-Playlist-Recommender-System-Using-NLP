# %% [markdown]
# # Recognizing and Handling bad lines (expected 4 elements separated by comas and got different number of elements)

# %%
import gdown
import pandas as pd

# Define the Google Drive file ID
file_id = '189D-QIh1J_3_S6qM7It3f20F0iN7Wvy-'

# Construct the download URL
download_url = f'https://drive.google.com/uc?export=download&id={file_id}'

# Output CSV file path
output_csv_path = 'spotify_dataset.csv'

# Download the file using gdown
gdown.download(download_url, output_csv_path, quiet=False)

# Load the CSV into a DataFrame
df_original = pd.read_csv(output_csv_path)

# Display the first few rows
df_original.head()
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=189D-QIh1J_3_S6qM7It3f20F0iN7Wvy-
# From (redirected): https://drive.google.com/uc?export=download&id=189D-QIh1J_3_S6qM7It3f20F0iN7Wvy-&confirm=t&uuid=a11e48dd-75f2-4869-b29f-77b4db486db9
# To: /content/spotify_dataset.csv
# 100%|██████████| 1.18G/1.18G [00:11<00:00, 101MB/s]
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-26-797d9ebd7dfb> in <cell line: 17>()
#      15
#      16 # Load the CSV into a DataFrame
# ---> 17 df_original = pd.read_csv(output_csv_path)
#      18
#      19 # Display the first few rows
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     624
#     625     with parser:
# --> 626         return parser.read(nrows)
#     627
#     628
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1921                     columns,
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#    1925                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 4 fields in line 14735, saw 5

# %% [markdown]
# Can't open the direct link because of bad lines in the dataset, lets check malformed rows:

# %%
with open(output_csv_path, 'r') as file, open('malformed_rows.csv', 'w') as malformed_file:
    for i, line in enumerate(file):
        if len(line.split(',')) != 4:  # Expected number of columns
            malformed_file.write(f"Line {i + 1}: {line}")

# %% [markdown]
# Expected 4 elements (=4 columns: user id, artistname, trackname, playlist) and got different result, meaning we need to put a quotechar = ' " ', that will recognize an element as one and not more than that because an element comes with brackets because it's a string.

# %% [markdown]
# # Direct link to the Spotify_playlist.csv dataset (no need to download)

# %%
import gdown
import pandas as pd

# Define the Google Drive file ID
file_id = '189D-QIh1J_3_S6qM7It3f20F0iN7Wvy-'

# Construct the download URL
download_url = f'https://drive.google.com/uc?export=download&id={file_id}'

# Output CSV file path
output_csv_path = 'spotify_dataset.csv'

# Download the file using gdown
gdown.download(download_url, output_csv_path, quiet=False)

# Load the CSV with proper handling of quoted fields
df_original = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', on_bad_lines='skip') # Some elements in one row have more than 4 elements (meaning 4 columns) because some track names (for example) contain comas
#so we implement a quotechasr='"' so a song will be read as one element.

# Display the first few rows
df_original.head()
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=189D-QIh1J_3_S6qM7It3f20F0iN7Wvy-
# From (redirected): https://drive.google.com/uc?export=download&id=189D-QIh1J_3_S6qM7It3f20F0iN7Wvy-&confirm=t&uuid=aa206aaa-6b00-4b7d-ae86-aeabbf5ebbea
# To: /content/spotify_dataset.csv
# 100%|██████████| 1.18G/1.18G [00:22<00:00, 52.3MB/s]
#                             user_id                      "artistname"  \
# 0  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2  9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
#
#                                          "trackname"  "playlistname"
# 0               (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1  (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                   7 Years Too Late  HARD ROCK 2010
# 3                              Accidents Will Happen  HARD ROCK 2010
# 4                                             Alison  HARD ROCK 2010

# %% [markdown]
# # Preliminary EDA (df=data frame)

# %% [markdown]
# escapechar handles the backslash \
#
# quotechar handles the coma inside a string ""

# %%
import gdown
import pandas as pd

# Direct link to your Google Drive file
file_id = '189D-QIh1J_3_S6qM7It3f20F0iN7Wvy-'
download_url = f'https://drive.google.com/uc?export=download&id={file_id}'

# Download the file to a local path
output_csv_path = 'spotify_dataset.csv'
gdown.download(download_url, output_csv_path, quiet=False)

# Load the CSV with pandas
df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
print(df.head())
# Out:
# Streaming output truncated to the last 5000 lines.
# Skipping line 6258854: expected 4 fields, saw 5
# Skipping line 6258856: expected 4 fields, saw 6
# Skipping line 6258858: expected 4 fields, saw 5
# Skipping line 6258861: expected 4 fields, saw 5
# Skipping line 6258863: expected 4 fields, saw 5
# Skipping line 6258870: expected 4 fields, saw 5
# Skipping line 6258873: expected 4 fields, saw 5
# Skipping line 6258874: expected 4 fields, saw 5
# Skipping line 6258875: expected 4 fields, saw 5
# Skipping line 6258878: expected 4 fields, saw 5
# Skipping line 6258879: expected 4 fields, saw 5
# Skipping line 6259203: expected 4 fields, saw 5
# Skipping line 6272218: expected 4 fields, saw 5
# Skipping line 6273536: expected 4 fields, saw 5
# Skipping line 6273560: expected 4 fields, saw 5
# Skipping line 6274127: expected 4 fields, saw 5
# Skipping line 6274855: expected 4 fields, saw 5
# Skipping line 6280493: expected 4 fields, saw 7
# Skipping line 6284775: expected 4 fields, saw 5
# Skipping line 6284802: expected 4 fields, saw 5
# Skipping line 6284859: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 6297850: expected 4 fields, saw 6
# Skipping line 6301615: expected 4 fields, saw 5
# Skipping line 6304155: expected 4 fields, saw 5
# Skipping line 6304194: expected 4 fields, saw 6
# Skipping line 6307891: expected 4 fields, saw 5
# Skipping line 6307915: expected 4 fields, saw 5
# Skipping line 6307966: expected 4 fields, saw 6
# Skipping line 6307973: expected 4 fields, saw 6
# Skipping line 6307974: expected 4 fields, saw 5
# Skipping line 6308799: expected 4 fields, saw 7
# Skipping line 6316301: expected 4 fields, saw 6
# Skipping line 6316495: expected 4 fields, saw 5
# Skipping line 6316499: expected 4 fields, saw 5
# Skipping line 6316844: expected 4 fields, saw 5
# Skipping line 6316865: expected 4 fields, saw 6
# Skipping line 6318588: expected 4 fields, saw 5
# Skipping line 6319714: expected 4 fields, saw 5
# Skipping line 6319793: expected 4 fields, saw 5
# Skipping line 6319804: expected 4 fields, saw 5
# Skipping line 6324319: expected 4 fields, saw 5
# Skipping line 6324320: expected 4 fields, saw 5
# Skipping line 6324321: expected 4 fields, saw 5
# Skipping line 6324322: expected 4 fields, saw 5
# Skipping line 6324325: expected 4 fields, saw 5
# Skipping line 6324540: expected 4 fields, saw 7
# Skipping line 6324736: expected 4 fields, saw 8
# Skipping line 6324768: expected 4 fields, saw 5
# Skipping line 6324914: expected 4 fields, saw 5
# Skipping line 6327105: expected 4 fields, saw 7
# Skipping line 6327106: expected 4 fields, saw 6
# Skipping line 6330429: expected 4 fields, saw 5
# Skipping line 6332323: expected 4 fields, saw 5
# Skipping line 6338479: expected 4 fields, saw 5
# Skipping line 6379795: expected 4 fields, saw 7
# Skipping line 6379798: expected 4 fields, saw 5
# Skipping line 6391159: expected 4 fields, saw 5
# Skipping line 6391279: expected 4 fields, saw 5
# Skipping line 6396920: expected 4 fields, saw 5
# Skipping line 6396921: expected 4 fields, saw 5
# Skipping line 6396922: expected 4 fields, saw 5
# Skipping line 6396923: expected 4 fields, saw 5
# Skipping line 6396924: expected 4 fields, saw 5
# Skipping line 6396925: expected 4 fields, saw 5
# Skipping line 6396926: expected 4 fields, saw 5
# Skipping line 6396927: expected 4 fields, saw 5
# Skipping line 6396928: expected 4 fields, saw 5
# Skipping line 6396929: expected 4 fields, saw 5
# Skipping line 6396930: expected 4 fields, saw 5
# Skipping line 6396931: expected 4 fields, saw 5
# Skipping line 6396932: expected 4 fields, saw 5
# Skipping line 6396933: expected 4 fields, saw 5
# Skipping line 6396934: expected 4 fields, saw 5
# Skipping line 6396935: expected 4 fields, saw 5
# Skipping line 6397551: expected 4 fields, saw 5
# Skipping line 6397663: expected 4 fields, saw 5
# Skipping line 6407785: expected 4 fields, saw 5
# Skipping line 6411921: expected 4 fields, saw 5
# Skipping line 6412821: expected 4 fields, saw 5
# Skipping line 6416017: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 6537980: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 6566098: expected 4 fields, saw 5
# Skipping line 6579242: expected 4 fields, saw 5
# Skipping line 6580004: expected 4 fields, saw 6
# Skipping line 6580047: expected 4 fields, saw 5
# Skipping line 6586126: expected 4 fields, saw 5
# Skipping line 6617138: expected 4 fields, saw 5
# Skipping line 6620299: expected 4 fields, saw 6
# Skipping line 6621703: expected 4 fields, saw 5
# Skipping line 6623436: expected 4 fields, saw 5
# Skipping line 6670672: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 6698261: expected 4 fields, saw 5
# Skipping line 6698262: expected 4 fields, saw 5
# Skipping line 6698271: expected 4 fields, saw 5
# Skipping line 6704638: expected 4 fields, saw 6
# Skipping line 6706123: expected 4 fields, saw 5
# Skipping line 6706340: expected 4 fields, saw 5
# Skipping line 6715863: expected 4 fields, saw 5
# Skipping line 6715888: expected 4 fields, saw 7
# Skipping line 6715902: expected 4 fields, saw 5
# Skipping line 6737086: expected 4 fields, saw 6
# Skipping line 6744509: expected 4 fields, saw 5
# Skipping line 6744510: expected 4 fields, saw 5
# Skipping line 6744512: expected 4 fields, saw 5
# Skipping line 6744513: expected 4 fields, saw 5
# Skipping line 6744514: expected 4 fields, saw 5
# Skipping line 6756662: expected 4 fields, saw 5
# Skipping line 6769817: expected 4 fields, saw 6
# Skipping line 6773165: expected 4 fields, saw 5
# Skipping line 6774893: expected 4 fields, saw 5
# Skipping line 6774910: expected 4 fields, saw 8
# Skipping line 6781112: expected 4 fields, saw 5
# Skipping line 6781150: expected 4 fields, saw 5
# Skipping line 6781163: expected 4 fields, saw 7
# Skipping line 6781239: expected 4 fields, saw 6
# Skipping line 6781246: expected 4 fields, saw 6
# Skipping line 6781247: expected 4 fields, saw 5
# Skipping line 6782514: expected 4 fields, saw 5
# Skipping line 6790441: expected 4 fields, saw 5
# Skipping line 6790479: expected 4 fields, saw 5
# Skipping line 6800528: expected 4 fields, saw 5
# Skipping line 6804113: expected 4 fields, saw 5
# Skipping line 6805537: expected 4 fields, saw 5
# Skipping line 6805561: expected 4 fields, saw 5
# Skipping line 6805612: expected 4 fields, saw 6
# Skipping line 6805619: expected 4 fields, saw 6
# Skipping line 6805620: expected 4 fields, saw 5
# Skipping line 6805640: expected 4 fields, saw 6
# Skipping line 6805642: expected 4 fields, saw 5
# Skipping line 6805680: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 6842308: expected 4 fields, saw 5
# Skipping line 6842337: expected 4 fields, saw 6
# Skipping line 6843505: expected 4 fields, saw 5
# Skipping line 6847840: expected 4 fields, saw 5
# Skipping line 6847868: expected 4 fields, saw 5
# Skipping line 6847869: expected 4 fields, saw 5
# Skipping line 6847871: expected 4 fields, saw 5
# Skipping line 6847873: expected 4 fields, saw 5
# Skipping line 6847874: expected 4 fields, saw 5
# Skipping line 6858821: expected 4 fields, saw 5
# Skipping line 6858967: expected 4 fields, saw 5
# Skipping line 6859988: expected 4 fields, saw 5
# Skipping line 6860254: expected 4 fields, saw 5
# Skipping line 6860511: expected 4 fields, saw 5
# Skipping line 6861444: expected 4 fields, saw 5
# Skipping line 6867882: expected 4 fields, saw 5
# Skipping line 6873422: expected 4 fields, saw 5
# Skipping line 6873650: expected 4 fields, saw 6
# Skipping line 6879400: expected 4 fields, saw 5
# Skipping line 6879401: expected 4 fields, saw 5
# Skipping line 6879402: expected 4 fields, saw 5
# Skipping line 6879404: expected 4 fields, saw 5
# Skipping line 6879405: expected 4 fields, saw 5
# Skipping line 6879406: expected 4 fields, saw 5
# Skipping line 6879412: expected 4 fields, saw 5
# Skipping line 6879416: expected 4 fields, saw 5
# Skipping line 6879417: expected 4 fields, saw 5
# Skipping line 6879419: expected 4 fields, saw 5
# Skipping line 6879420: expected 4 fields, saw 5
# Skipping line 6879427: expected 4 fields, saw 5
# Skipping line 6879428: expected 4 fields, saw 5
# Skipping line 6879430: expected 4 fields, saw 5
# Skipping line 6879431: expected 4 fields, saw 5
# Skipping line 6879433: expected 4 fields, saw 5
# Skipping line 6879434: expected 4 fields, saw 5
# Skipping line 6879436: expected 4 fields, saw 5
# Skipping line 6879442: expected 4 fields, saw 5
# Skipping line 6879452: expected 4 fields, saw 5
# Skipping line 6879453: expected 4 fields, saw 5
# Skipping line 6879454: expected 4 fields, saw 5
# Skipping line 6879459: expected 4 fields, saw 5
# Skipping line 6879460: expected 4 fields, saw 5
# Skipping line 6879461: expected 4 fields, saw 5
# Skipping line 6879466: expected 4 fields, saw 5
# Skipping line 6879467: expected 4 fields, saw 5
# Skipping line 6879468: expected 4 fields, saw 5
# Skipping line 6879481: expected 4 fields, saw 5
# Skipping line 6879482: expected 4 fields, saw 5
# Skipping line 6879483: expected 4 fields, saw 5
# Skipping line 6879484: expected 4 fields, saw 5
# Skipping line 6879493: expected 4 fields, saw 5
# Skipping line 6879497: expected 4 fields, saw 5
# Skipping line 6879498: expected 4 fields, saw 5
# Skipping line 6879499: expected 4 fields, saw 5
# Skipping line 6879502: expected 4 fields, saw 5
# Skipping line 6879503: expected 4 fields, saw 5
# Skipping line 6879508: expected 4 fields, saw 5
# Skipping line 6879509: expected 4 fields, saw 5
# Skipping line 6879510: expected 4 fields, saw 5
# Skipping line 6879512: expected 4 fields, saw 5
# Skipping line 6879513: expected 4 fields, saw 5
# Skipping line 6879514: expected 4 fields, saw 5
# Skipping line 6879525: expected 4 fields, saw 5
# Skipping line 6879526: expected 4 fields, saw 5
# Skipping line 6879527: expected 4 fields, saw 5
# Skipping line 6879539: expected 4 fields, saw 5
# Skipping line 6879540: expected 4 fields, saw 5
# Skipping line 6879541: expected 4 fields, saw 5
# Skipping line 6879545: expected 4 fields, saw 5
# Skipping line 6879552: expected 4 fields, saw 5
# Skipping line 6879553: expected 4 fields, saw 5
# Skipping line 6879554: expected 4 fields, saw 5
# Skipping line 6879556: expected 4 fields, saw 5
# Skipping line 6879557: expected 4 fields, saw 5
# Skipping line 6879558: expected 4 fields, saw 5
# Skipping line 6879562: expected 4 fields, saw 5
# Skipping line 6879563: expected 4 fields, saw 5
# Skipping line 6879564: expected 4 fields, saw 5
# Skipping line 6879565: expected 4 fields, saw 5
# Skipping line 6884139: expected 4 fields, saw 6
# Skipping line 6884185: expected 4 fields, saw 5
# Skipping line 6884186: expected 4 fields, saw 5
# Skipping line 6884191: expected 4 fields, saw 7
# Skipping line 6898343: expected 4 fields, saw 5
# Skipping line 6908554: expected 4 fields, saw 5
# Skipping line 6913012: expected 4 fields, saw 5
# Skipping line 6914654: expected 4 fields, saw 5
# Skipping line 6919783: expected 4 fields, saw 5
# Skipping line 6926813: expected 4 fields, saw 5
# Skipping line 6926836: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 6953956: expected 4 fields, saw 7
# Skipping line 6953957: expected 4 fields, saw 6
# Skipping line 6954793: expected 4 fields, saw 5
# Skipping line 6958974: expected 4 fields, saw 5
# Skipping line 6962100: expected 4 fields, saw 5
# Skipping line 6962122: expected 4 fields, saw 5
# Skipping line 6966832: expected 4 fields, saw 5
# Skipping line 6967290: expected 4 fields, saw 5
# Skipping line 6967990: expected 4 fields, saw 5
# Skipping line 6968033: expected 4 fields, saw 5
# Skipping line 6970575: expected 4 fields, saw 5
# Skipping line 6970576: expected 4 fields, saw 5
# Skipping line 6970577: expected 4 fields, saw 5
# Skipping line 6970578: expected 4 fields, saw 5
# Skipping line 6970579: expected 4 fields, saw 5
# Skipping line 6970580: expected 4 fields, saw 5
# Skipping line 6970581: expected 4 fields, saw 5
# Skipping line 6970582: expected 4 fields, saw 5
# Skipping line 6970583: expected 4 fields, saw 5
# Skipping line 6970584: expected 4 fields, saw 5
# Skipping line 6970585: expected 4 fields, saw 5
# Skipping line 6970586: expected 4 fields, saw 5
# Skipping line 6970587: expected 4 fields, saw 5
# Skipping line 6970588: expected 4 fields, saw 5
# Skipping line 6970589: expected 4 fields, saw 5
# Skipping line 6970590: expected 4 fields, saw 5
# Skipping line 6971443: expected 4 fields, saw 5
# Skipping line 6975003: expected 4 fields, saw 5
# Skipping line 6975025: expected 4 fields, saw 5
# Skipping line 6975821: expected 4 fields, saw 5
# Skipping line 6977161: expected 4 fields, saw 5
# Skipping line 6977275: expected 4 fields, saw 5
# Skipping line 6977279: expected 4 fields, saw 5
# Skipping line 6977291: expected 4 fields, saw 5
# Skipping line 6977323: expected 4 fields, saw 5
# Skipping line 6977325: expected 4 fields, saw 5
# Skipping line 6977381: expected 4 fields, saw 5
# Skipping line 6977382: expected 4 fields, saw 5
# Skipping line 6977383: expected 4 fields, saw 5
# Skipping line 6977392: expected 4 fields, saw 5
# Skipping line 6977444: expected 4 fields, saw 5
# Skipping line 6977469: expected 4 fields, saw 5
# Skipping line 6977471: expected 4 fields, saw 5
# Skipping line 6977477: expected 4 fields, saw 5
# Skipping line 6977502: expected 4 fields, saw 5
# Skipping line 6977517: expected 4 fields, saw 6
# Skipping line 6977523: expected 4 fields, saw 5
# Skipping line 6977559: expected 4 fields, saw 5
# Skipping line 6977566: expected 4 fields, saw 5
# Skipping line 6977570: expected 4 fields, saw 5
# Skipping line 6977571: expected 4 fields, saw 5
# Skipping line 6977579: expected 4 fields, saw 5
# Skipping line 6983882: expected 4 fields, saw 5
# Skipping line 6983883: expected 4 fields, saw 5
# Skipping line 6983884: expected 4 fields, saw 5
# Skipping line 6983885: expected 4 fields, saw 5
# Skipping line 6983886: expected 4 fields, saw 5
# Skipping line 6983887: expected 4 fields, saw 5
# Skipping line 6983888: expected 4 fields, saw 5
# Skipping line 6983889: expected 4 fields, saw 5
# Skipping line 6983890: expected 4 fields, saw 5
# Skipping line 6983891: expected 4 fields, saw 5
# Skipping line 6983892: expected 4 fields, saw 5
# Skipping line 6983893: expected 4 fields, saw 5
# Skipping line 6983894: expected 4 fields, saw 5
# Skipping line 6983895: expected 4 fields, saw 5
# Skipping line 6983896: expected 4 fields, saw 5
# Skipping line 6983897: expected 4 fields, saw 5
# Skipping line 6983898: expected 4 fields, saw 5
# Skipping line 6983899: expected 4 fields, saw 5
# Skipping line 6983900: expected 4 fields, saw 5
# Skipping line 6983901: expected 4 fields, saw 5
# Skipping line 6984210: expected 4 fields, saw 5
# Skipping line 6985557: expected 4 fields, saw 5
# Skipping line 6991758: expected 4 fields, saw 6
# Skipping line 7005819: expected 4 fields, saw 5
# Skipping line 7012825: expected 4 fields, saw 6
# Skipping line 7035417: expected 4 fields, saw 5
# Skipping line 7052079: expected 4 fields, saw 5
# Skipping line 7065264: expected 4 fields, saw 5
# Skipping line 7066220: expected 4 fields, saw 5
# Skipping line 7066248: expected 4 fields, saw 6
# Skipping line 7066541: expected 4 fields, saw 5
# Skipping line 7070432: expected 4 fields, saw 5
# Skipping line 7070457: expected 4 fields, saw 5
# Skipping line 7072038: expected 4 fields, saw 5
# Skipping line 7083059: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 7093414: expected 4 fields, saw 6
# Skipping line 7093415: expected 4 fields, saw 6
# Skipping line 7093416: expected 4 fields, saw 6
# Skipping line 7093417: expected 4 fields, saw 6
# Skipping line 7094422: expected 4 fields, saw 5
# Skipping line 7099008: expected 4 fields, saw 6
# Skipping line 7099011: expected 4 fields, saw 5
# Skipping line 7099078: expected 4 fields, saw 5
# Skipping line 7100187: expected 4 fields, saw 6
# Skipping line 7101725: expected 4 fields, saw 5
# Skipping line 7101726: expected 4 fields, saw 5
# Skipping line 7109597: expected 4 fields, saw 5
# Skipping line 7110345: expected 4 fields, saw 5
# Skipping line 7121671: expected 4 fields, saw 220
# Skipping line 7122500: expected 4 fields, saw 5
# Skipping line 7128248: expected 4 fields, saw 5
# Skipping line 7132371: expected 4 fields, saw 5
# Skipping line 7132375: expected 4 fields, saw 5
# Skipping line 7132376: expected 4 fields, saw 6
# Skipping line 7132378: expected 4 fields, saw 6
# Skipping line 7132381: expected 4 fields, saw 6
# Skipping line 7132392: expected 4 fields, saw 5
# Skipping line 7132393: expected 4 fields, saw 6
# Skipping line 7132396: expected 4 fields, saw 6
# Skipping line 7132400: expected 4 fields, saw 5
# Skipping line 7132402: expected 4 fields, saw 6
# Skipping line 7132410: expected 4 fields, saw 5
# Skipping line 7132415: expected 4 fields, saw 6
# Skipping line 7132416: expected 4 fields, saw 6
# Skipping line 7132417: expected 4 fields, saw 5
# Skipping line 7132420: expected 4 fields, saw 5
# Skipping line 7132425: expected 4 fields, saw 5
# Skipping line 7132427: expected 4 fields, saw 6
# Skipping line 7132431: expected 4 fields, saw 6
# Skipping line 7132443: expected 4 fields, saw 5
# Skipping line 7132444: expected 4 fields, saw 6
# Skipping line 7132451: expected 4 fields, saw 5
# Skipping line 7132556: expected 4 fields, saw 5
# Skipping line 7132558: expected 4 fields, saw 5
# Skipping line 7132731: expected 4 fields, saw 5
# Skipping line 7132827: expected 4 fields, saw 7
# Skipping line 7132828: expected 4 fields, saw 6
# Skipping line 7132830: expected 4 fields, saw 6
# Skipping line 7132832: expected 4 fields, saw 5
# Skipping line 7132833: expected 4 fields, saw 5
# Skipping line 7132836: expected 4 fields, saw 5
# Skipping line 7133261: expected 4 fields, saw 5
# Skipping line 7141569: expected 4 fields, saw 5
# Skipping line 7141574: expected 4 fields, saw 5
# Skipping line 7141578: expected 4 fields, saw 5
# Skipping line 7141581: expected 4 fields, saw 5
# Skipping line 7142136: expected 4 fields, saw 7
# Skipping line 7142611: expected 4 fields, saw 6
# Skipping line 7144787: expected 4 fields, saw 5
# Skipping line 7144792: expected 4 fields, saw 5
# Skipping line 7144796: expected 4 fields, saw 5
# Skipping line 7144799: expected 4 fields, saw 5
# Skipping line 7147835: expected 4 fields, saw 6
# Skipping line 7151999: expected 4 fields, saw 5
# Skipping line 7152516: expected 4 fields, saw 5
# Skipping line 7152517: expected 4 fields, saw 5
# Skipping line 7152519: expected 4 fields, saw 5
# Skipping line 7152532: expected 4 fields, saw 5
# Skipping line 7152549: expected 4 fields, saw 5
# Skipping line 7152550: expected 4 fields, saw 5
# Skipping line 7152553: expected 4 fields, saw 5
# Skipping line 7152721: expected 4 fields, saw 10
# Skipping line 7152724: expected 4 fields, saw 6
# Skipping line 7152725: expected 4 fields, saw 6
# Skipping line 7152726: expected 4 fields, saw 5
# Skipping line 7152727: expected 4 fields, saw 5
# Skipping line 7152728: expected 4 fields, saw 9
# Skipping line 7152729: expected 4 fields, saw 5
# Skipping line 7152732: expected 4 fields, saw 7
# Skipping line 7152733: expected 4 fields, saw 7
# Skipping line 7152734: expected 4 fields, saw 5
# Skipping line 7152735: expected 4 fields, saw 6
# Skipping line 7152737: expected 4 fields, saw 5
# Skipping line 7152740: expected 4 fields, saw 5
# Skipping line 7152743: expected 4 fields, saw 5
# Skipping line 7152744: expected 4 fields, saw 11
# Skipping line 7152745: expected 4 fields, saw 14
# Skipping line 7152746: expected 4 fields, saw 6
# Skipping line 7152747: expected 4 fields, saw 8
# Skipping line 7152748: expected 4 fields, saw 11
# Skipping line 7152750: expected 4 fields, saw 7
# Skipping line 7152751: expected 4 fields, saw 9
# Skipping line 7152752: expected 4 fields, saw 5
# Skipping line 7152753: expected 4 fields, saw 5
# Skipping line 7152754: expected 4 fields, saw 5
# Skipping line 7152755: expected 4 fields, saw 6
# Skipping line 7152756: expected 4 fields, saw 6
# Skipping line 7152758: expected 4 fields, saw 7
# Skipping line 7152759: expected 4 fields, saw 7
# Skipping line 7152760: expected 4 fields, saw 8
# Skipping line 7153176: expected 4 fields, saw 7
# Skipping line 7153190: expected 4 fields, saw 5
# Skipping line 7153229: expected 4 fields, saw 5
# Skipping line 7153256: expected 4 fields, saw 5
# Skipping line 7153274: expected 4 fields, saw 5
# Skipping line 7153295: expected 4 fields, saw 6
# Skipping line 7153316: expected 4 fields, saw 5
# Skipping line 7161562: expected 4 fields, saw 5
# Skipping line 7162835: expected 4 fields, saw 5
# Skipping line 7163234: expected 4 fields, saw 5
# Skipping line 7167455: expected 4 fields, saw 6
# Skipping line 7169525: expected 4 fields, saw 6
# Skipping line 7170278: expected 4 fields, saw 5
# Skipping line 7170298: expected 4 fields, saw 5
# Skipping line 7170299: expected 4 fields, saw 6
# Skipping line 7170301: expected 4 fields, saw 5
# Skipping line 7170305: expected 4 fields, saw 5
# Skipping line 7170317: expected 4 fields, saw 7
# Skipping line 7170319: expected 4 fields, saw 5
# Skipping line 7170320: expected 4 fields, saw 5
# Skipping line 7170322: expected 4 fields, saw 5
# Skipping line 7170326: expected 4 fields, saw 6
# Skipping line 7170327: expected 4 fields, saw 7
# Skipping line 7170329: expected 4 fields, saw 6
# Skipping line 7170335: expected 4 fields, saw 8
# Skipping line 7170337: expected 4 fields, saw 5
# Skipping line 7170338: expected 4 fields, saw 7
# Skipping line 7170343: expected 4 fields, saw 5
# Skipping line 7170344: expected 4 fields, saw 5
# Skipping line 7171020: expected 4 fields, saw 5
# Skipping line 7172895: expected 4 fields, saw 5
# Skipping line 7173629: expected 4 fields, saw 6
# Skipping line 7178468: expected 4 fields, saw 6
# Skipping line 7185905: expected 4 fields, saw 5
# Skipping line 7193252: expected 4 fields, saw 5
# Skipping line 7195976: expected 4 fields, saw 5
# Skipping line 7197820: expected 4 fields, saw 6
# Skipping line 7200197: expected 4 fields, saw 5
# Skipping line 7200198: expected 4 fields, saw 6
# Skipping line 7200200: expected 4 fields, saw 5
# Skipping line 7200204: expected 4 fields, saw 5
# Skipping line 7200702: expected 4 fields, saw 7
# Skipping line 7200711: expected 4 fields, saw 8
# Skipping line 7204821: expected 4 fields, saw 5
# Skipping line 7204899: expected 4 fields, saw 5
# Skipping line 7210010: expected 4 fields, saw 5
# Skipping line 7210011: expected 4 fields, saw 5
# Skipping line 7210015: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 7217036: expected 4 fields, saw 5
# Skipping line 7229013: expected 4 fields, saw 5
# Skipping line 7249657: expected 4 fields, saw 5
# Skipping line 7251919: expected 4 fields, saw 5
# Skipping line 7264837: expected 4 fields, saw 5
# Skipping line 7264840: expected 4 fields, saw 5
# Skipping line 7282049: expected 4 fields, saw 5
# Skipping line 7282074: expected 4 fields, saw 5
# Skipping line 7289238: expected 4 fields, saw 5
# Skipping line 7290445: expected 4 fields, saw 5
# Skipping line 7659950: expected 4 fields, saw 5
# Skipping line 7660144: expected 4 fields, saw 5
# Skipping line 7662430: expected 4 fields, saw 6
# Skipping line 7665274: expected 4 fields, saw 5
# Skipping line 7665496: expected 4 fields, saw 5
# Skipping line 7665502: expected 4 fields, saw 5
# Skipping line 7668715: expected 4 fields, saw 5
# Skipping line 7672118: expected 4 fields, saw 5
# Skipping line 7684002: expected 4 fields, saw 5
# Skipping line 7693081: expected 4 fields, saw 5
# Skipping line 7709295: expected 4 fields, saw 5
# Skipping line 7711701: expected 4 fields, saw 5
# Skipping line 7720172: expected 4 fields, saw 5
# Skipping line 7728132: expected 4 fields, saw 6
# Skipping line 7734862: expected 4 fields, saw 6
# Skipping line 7735493: expected 4 fields, saw 5
# Skipping line 7735577: expected 4 fields, saw 5
# Skipping line 7736423: expected 4 fields, saw 5
# Skipping line 7736636: expected 4 fields, saw 6
# Skipping line 7736638: expected 4 fields, saw 5
# Skipping line 7738755: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 7742242: expected 4 fields, saw 5
# Skipping line 7743938: expected 4 fields, saw 5
# Skipping line 7751974: expected 4 fields, saw 7
# Skipping line 7765977: expected 4 fields, saw 244
# Skipping line 7771631: expected 4 fields, saw 5
# Skipping line 7771694: expected 4 fields, saw 5
# Skipping line 7775165: expected 4 fields, saw 5
# Skipping line 7775170: expected 4 fields, saw 5
# Skipping line 7775174: expected 4 fields, saw 6
# Skipping line 7775213: expected 4 fields, saw 6
# Skipping line 7775361: expected 4 fields, saw 7
# Skipping line 7775842: expected 4 fields, saw 5
# Skipping line 7775843: expected 4 fields, saw 5
# Skipping line 7775844: expected 4 fields, saw 5
# Skipping line 7775845: expected 4 fields, saw 5
# Skipping line 7775846: expected 4 fields, saw 5
# Skipping line 7775847: expected 4 fields, saw 5
# Skipping line 7775848: expected 4 fields, saw 5
# Skipping line 7775849: expected 4 fields, saw 5
# Skipping line 7775850: expected 4 fields, saw 5
# Skipping line 7775851: expected 4 fields, saw 5
# Skipping line 7775852: expected 4 fields, saw 5
# Skipping line 7775853: expected 4 fields, saw 5
# Skipping line 7775854: expected 4 fields, saw 5
# Skipping line 7775855: expected 4 fields, saw 5
# Skipping line 7775856: expected 4 fields, saw 5
# Skipping line 7775857: expected 4 fields, saw 5
# Skipping line 7775858: expected 4 fields, saw 5
# Skipping line 7775859: expected 4 fields, saw 5
# Skipping line 7775860: expected 4 fields, saw 5
# Skipping line 7775861: expected 4 fields, saw 5
# Skipping line 7775965: expected 4 fields, saw 7
# Skipping line 7785450: expected 4 fields, saw 6
# Skipping line 7791206: expected 4 fields, saw 5
# Skipping line 7793237: expected 4 fields, saw 6
# Skipping line 7793298: expected 4 fields, saw 5
# Skipping line 7793299: expected 4 fields, saw 5
# Skipping line 7794863: expected 4 fields, saw 5
# Skipping line 7805370: expected 4 fields, saw 5
# Skipping line 7812010: expected 4 fields, saw 5
# Skipping line 7816929: expected 4 fields, saw 5
# Skipping line 7817284: expected 4 fields, saw 5
# Skipping line 7817296: expected 4 fields, saw 5
# Skipping line 7832370: expected 4 fields, saw 5
# Skipping line 7832648: expected 4 fields, saw 5
# Skipping line 7845539: expected 4 fields, saw 6
# Skipping line 7846494: expected 4 fields, saw 5
# Skipping line 7846664: expected 4 fields, saw 5
# Skipping line 7846762: expected 4 fields, saw 5
# Skipping line 7846922: expected 4 fields, saw 6
# Skipping line 7860876: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line
expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 8005139: expected 4 fields, saw 6
# Skipping line 8024413: expected 4 fields, saw 5
# Skipping line 8026340: expected 4 fields, saw 5
# Skipping line 8027525: expected 4 fields, saw 5
# Skipping line 8035858: expected 4 fields, saw 5
# Skipping line 8035863: expected 4 fields, saw 6
# Skipping line 8035907: expected 4 fields, saw 5
# Skipping line 8035939: expected 4 fields, saw 5
# Skipping line 8035941: expected 4 fields, saw 5
# Skipping line 8035943: expected 4 fields, saw 5
# Skipping line 8035944: expected 4 fields, saw 5
# Skipping line 8035945: expected 4 fields, saw 5
# Skipping line 8035946: expected 4 fields, saw 7
# Skipping line 8035947: expected 4 fields, saw 5
# Skipping line 8035948: expected 4 fields, saw 7
# Skipping line 8035949: expected 4 fields, saw 6
# Skipping line 8035950: expected 4 fields, saw 5
# Skipping line 8035951: expected 4 fields, saw 8
# Skipping line 8035952: expected 4 fields, saw 5
# Skipping line 8035953: expected 4 fields, saw 6
# Skipping line 8035954: expected 4 fields, saw 5
# Skipping line 8036093: expected 4 fields, saw 5
# Skipping line 8036224: expected 4 fields, saw 5
# Skipping line 8036422: expected 4 fields, saw 8
# Skipping line 8036594: expected 4 fields, saw 5
# Skipping line 8036670: expected 4 fields, saw 5
# Skipping line 8036671: expected 4 fields, saw 5
# Skipping line 8037527: expected 4 fields, saw 5
# Skipping line 8047106: expected 4 fields, saw 6
# Skipping line 8052993: expected 4 fields, saw 5
# Skipping line 8062287: expected 4 fields, saw 5
# Skipping line 8062288: expected 4 fields, saw 5
# Skipping line 8062289: expected 4 fields, saw 5
# Skipping line 8062407: expected 4 fields, saw 5
# Skipping line 8062419: expected 4 fields, saw 5
# Skipping line 8062420: expected 4 fields, saw 5
# Skipping line 8062422: expected 4 fields, saw 5
# Skipping line 8063493: expected 4 fields, saw 5
# Skipping line 8063494: expected 4 fields, saw 5
# Skipping line 8063495: expected 4 fields, saw 5
# Skipping line 8063497: expected 4 fields, saw 5
# Skipping line 8063506: expected 4 fields, saw 5
# Skipping line 8065401: expected 4 fields, saw 7
# Skipping line 8065594: expected 4 fields, saw 5
# Skipping line 8065631: expected 4 fields, saw 5
# Skipping line 8069042: expected 4 fields, saw 6
# Skipping line 8069043: expected 4 fields, saw 6
# Skipping line 8069044: expected 4 fields, saw 5
# Skipping line 8069050: expected 4 fields, saw 6
# Skipping line 8069057: expected 4 fields, saw 5
# Skipping line 8069060: expected 4 fields, saw 5
# Skipping line 8069062: expected 4 fields, saw 5
# Skipping line 8069063: expected 4 fields, saw 5
# Skipping line 8069064: expected 4 fields, saw 5
# Skipping line 8069066: expected 4 fields, saw 7
# Skipping line 8069068: expected 4 fields, saw 5
# Skipping line 8069073: expected 4 fields, saw 6
# Skipping line 8069075: expected 4 fields, saw 5
# Skipping line 8069080: expected 4 fields, saw 5
# Skipping line 8069084: expected 4 fields, saw 5
# Skipping line 8069085: expected 4 fields, saw 5
# Skipping line 8069089: expected 4 fields, saw 6
# Skipping line 8069180: expected 4 fields, saw 5
# Skipping line 8069190: expected 4 fields, saw 5
# Skipping line 8069198: expected 4 fields, saw 6
# Skipping line 8069199: expected 4 fields, saw 7
# Skipping line 8069200: expected 4 fields, saw 5
# Skipping line 8069204: expected 4 fields, saw 5
# Skipping line 8069205: expected 4 fields, saw 5
# Skipping line 8069206: expected 4 fields, saw 5
# Skipping line 8069215: expected 4 fields, saw 5
# Skipping line 8069989: expected 4 fields, saw 5
# Skipping line 8069991: expected 4 fields, saw 7
# Skipping line 8070441: expected 4 fields, saw 5
# Skipping line 8079671: expected 4 fields, saw 5
# Skipping line 8080204: expected 4 fields, saw 5
# Skipping line 8080276: expected 4 fields, saw 5
# Skipping line 8080676: expected 4 fields, saw 5
# Skipping line 8080677: expected 4 fields, saw 5
# Skipping line 8080678: expected 4 fields, saw 5
# Skipping line 8087423: expected 4 fields, saw 5
# Skipping line 8087538: expected 4 fields, saw 5
# Skipping line 8087561: expected 4 fields, saw 5
# Skipping line 8088037: expected 4 fields, saw 5
# Skipping line 8088789: expected 4 fields, saw 5
# Skipping line 8088881: expected 4 fields, saw 5
# Skipping line 8088882: expected 4 fields, saw 5
# Skipping line 8089149: expected 4 fields, saw 5
# Skipping line 8089688: expected 4 fields, saw 5
# Skipping line 8090104: expected 4 fields, saw 5
# Skipping line 8090105: expected 4 fields, saw 5
# Skipping line 8093675: expected 4 fields, saw 5
# Skipping line 8102497: expected 4 fields, saw 6
# Skipping line 8104273: expected 4 fields, saw 5
# Skipping line 8104274: expected 4 fields, saw 5
# Skipping line 8104284: expected 4 fields, saw 5
# Skipping line 8106170: expected 4 fields, saw 5
# Skipping line 8129087: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 8137188: expected 4 fields, saw 5
# Skipping line 8137446: expected 4 fields, saw 5
# Skipping line 8155064: expected 4 fields, saw 6
# Skipping line 8155065: expected 4 fields, saw 6
# Skipping line 8155066: expected 4 fields, saw 6
# Skipping line 8155067: expected 4 fields, saw 6
# Skipping line 8155106: expected 4 fields, saw 6
# Skipping line 8155107: expected 4 fields, saw 6
# Skipping line 8155108: expected 4 fields, saw 6
# Skipping line 8155109: expected 4 fields, saw 6
# Skipping line 8155110: expected 4 fields, saw 6
# Skipping line 8162059: expected 4 fields, saw 6
# Skipping line 8175333: expected 4 fields, saw 5
# Skipping line 8187911: expected 4 fields, saw 5
# Skipping line 8200281: expected 4 fields, saw 5
# Skipping line 8211116: expected 4 fields, saw 5
# Skipping line 8213924: expected 4 fields, saw 5
# Skipping line 8213952: expected 4 fields, saw 5
# Skipping line 8213956: expected 4 fields, saw 5
# Skipping line 8214259: expected 4 fields, saw 5
# Skipping line 8222056: expected 4 fields, saw 5
# Skipping line 8223792: expected 4 fields, saw 5
# Skipping line 8223794: expected 4 fields, saw 5
# Skipping line 8223795: expected 4 fields, saw 5
# Skipping line 8223796: expected 4 fields, saw 5
# Skipping line 8223799: expected 4 fields, saw 5
# Skipping line 8223800: expected 4 fields, saw 5
# Skipping line 8223801: expected 4 fields, saw 5
# Skipping line 8223802: expected 4 fields, saw 6
# Skipping line 8223803: expected 4 fields, saw 5
# Skipping line 8223804: expected 4 fields, saw 5
# Skipping line 8223806: expected 4 fields, saw 5
# Skipping line 8223810: expected 4 fields, saw 6
# Skipping line 8223811: expected 4 fields, saw 5
# Skipping line 8223812: expected 4 fields, saw 5
# Skipping line 8223814: expected 4 fields, saw 7
# Skipping line 8223825: expected 4 fields, saw 6
# Skipping line 8224542: expected 4 fields, saw 5
# Skipping line 8236730: expected 4 fields, saw 8
# Skipping line 8246141: expected 4 fields, saw 6
# Skipping line 8246142: expected 4 fields, saw 7
# Skipping line 8246143: expected 4 fields, saw 5
# Skipping line 8246144: expected 4 fields, saw 5
# Skipping line 8246145: expected 4 fields, saw 8
# Skipping line 8246146: expected 4 fields, saw 5
# Skipping line 8246147: expected 4 fields, saw 5
# Skipping line 8246148: expected 4 fields, saw 7
# Skipping line 8246149: expected 4 fields, saw 5
# Skipping line 8246150: expected 4 fields, saw 5
# Skipping line 8246151: expected 4 fields, saw 9
# Skipping line 8246152: expected 4 fields, saw 8
# Skipping line 8246153: expected 4 fields, saw 10
# Skipping line 8246154: expected 4 fields, saw 9
# Skipping line 8246155: expected 4 fields, saw 6
# Skipping line 8246156: expected 4 fields, saw 7
# Skipping line 8246157: expected 4 fields, saw 7
# Skipping line 8246158: expected 4 fields, saw 8
# Skipping line 8246159: expected 4 fields, saw 8
# Skipping line 8246160: expected 4 fields, saw 5
# Skipping line 8246161: expected 4 fields, saw 6
# Skipping line 8246162: expected 4 fields, saw 6
# Skipping line 8246163: expected 4 fields, saw 6
# ...
# Skipping line 12323063: expected 4 fields, saw 5
# Skipping line 12323067: expected 4 fields, saw 5
# Skipping line 12323072: expected 4 fields, saw 6
# Skipping line 12323114: expected 4 fields, saw 6
# Skipping line 12323115: expected 4 fields, saw 6
# Skipping line 12323117: expected 4 fields, saw 6
# Skipping line 12323119: expected 4 fields, saw 5
# Skipping line 12323120: expected 4 fields, saw 5
# Skipping line 12323122: expected 4 fields, saw 5
# Skipping line 12323123: expected 4 fields, saw 5
# Skipping line 12323149: expected 4 fields, saw 5
# Skipping line 12323569: expected 4 fields, saw 6
# Skipping line 12323588: expected 4 fields, saw 6
# Skipping line 12323830: expected 4 fields, saw 5
# Skipping line 12323831: expected 4 fields, saw 5
# Skipping line 12323832: expected 4 fields, saw 5
# Skipping line 12323833: expected 4 fields, saw 5
# Skipping line 12323931: expected 4 fields, saw 6
# Skipping line 12323968: expected 4 fields, saw 5
# Skipping line 12323969: expected 4 fields, saw 5
# Skipping line 12323970: expected 4 fields, saw 5
# Skipping line 12324138: expected 4 fields, saw 5
# Skipping line 12324141: expected 4 fields, saw 5
# Skipping line 12324143: expected 4 fields, saw 5
# Skipping line 12324148: expected 4 fields, saw 7
# Skipping line 12324215: expected 4 fields, saw 7
# Skipping line 12324275: expected 4 fields, saw 5
# Skipping line 12324276: expected 4 fields, saw 5
# Skipping line 12324277: expected 4 fields, saw 5
# Skipping line 12324278: expected 4 fields, saw 5
# Skipping line 12324279: expected 4 fields, saw 5
# Skipping line 12324280: expected 4 fields, saw 5
# Skipping line 12324281: expected 4 fields, saw 5
# Skipping line 12324282: expected 4 fields, saw 5
# Skipping line 12324283: expected 4 fields, saw 5
# Skipping line 12324284: expected 4 fields, saw 5
# Skipping line 12324285: expected 4 fields, saw 5
# Skipping line 12324286: expected 4 fields, saw 5
# Skipping line 12324287: expected 4 fields, saw 5
# Skipping line 12324292: expected 4 fields, saw 8
# Skipping line 12324293: expected 4 fields, saw 8
# Skipping line 12324299: expected 4 fields, saw 6
# Skipping line 12324300: expected 4 fields, saw 6
# Skipping line 12324528: expected 4 fields, saw 5
# Skipping line 12324548: expected 4 fields, saw 5
# Skipping line 12324550: expected 4 fields, saw 5
# Skipping line 12324720: expected 4 fields, saw 7
# Skipping line 12324721: expected 4 fields, saw 6
# Skipping line 12324723: expected 4 fields, saw 5
# Skipping line 12324729: expected 4 fields, saw 5
# Skipping line 12325244: expected 4 fields, saw 6
# Skipping line 12325277: expected 4 fields, saw 5
# Skipping line 12325307: expected 4 fields, saw 5
# Skipping line 12325587: expected 4 fields, saw 5
# Skipping line 12325596: expected 4 fields, saw 5
# Skipping line 12325758: expected 4 fields, saw 5
# Skipping line 12325786: expected 4 fields, saw 6
# Skipping line 12325829: expected 4 fields, saw 5
# Skipping line 12325916: expected 4 fields, saw 5
# Skipping line 12325919: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 12347289: expected 4 fields, saw 10
# Skipping line 12350104: expected 4 fields, saw 5
# Skipping line 12357717: expected 4 fields, saw 5
# Skipping line 12357738: expected 4 fields, saw 6
# Skipping line 12394194: expected 4 fields, saw 5
# Skipping line 12396268: expected 4 fields, saw 5
# Skipping line 12398861: expected 4 fields, saw 6
# Skipping line 12404152: expected 4 fields, saw 5
# Skipping line 12404852: expected 4 fields, saw 5
# Skipping line 12416056: expected 4 fields, saw 5
# Skipping line 12420716: expected 4 fields, saw 5
# Skipping line 12431121: expected 4 fields, saw 5
# Skipping line 12439995: expected 4 fields, saw 5
# Skipping line 12443800: expected 4 fields, saw 5
# Skipping line 12443801: expected 4 fields, saw 6
# Skipping line 12443803: expected 4 fields, saw 5
# Skipping line 12443807: expected 4 fields, saw 5
# Skipping line 12443895: expected 4 fields, saw 5
# Skipping line 12444011: expected 4 fields, saw 5
# Skipping line 12444144: expected 4 fields, saw 5
# Skipping line 12444149: expected 4 fields, saw 5
# Skipping line 12445412: expected 4 fields, saw 5
# Skipping line 12445913: expected 4 fields, saw 5
# Skipping line 12449501: expected 4 fields, saw 6
# Skipping line 12450542: expected 4 fields, saw 5
# Skipping line 12452495: expected 4 fields, saw 5
# Skipping line 12456312: expected 4 fields, saw 5
# Skipping line 12456335: expected 4 fields, saw 5
# Skipping line 12456423: expected 4 fields, saw 5
# Skipping line 12456447: expected 4 fields, saw 5
# Skipping line 12456498: expected 4 fields, saw 6
# Skipping line 12456505: expected 4 fields, saw 6
# Skipping line 12456506: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 12470025: expected 4 fields, saw 5
# Skipping line 12471178: expected 4 fields, saw 5
# Skipping line 12478268: expected 4 fields, saw 5
# Skipping line 12480505: expected 4 fields, saw 5
# Skipping line 12480705: expected 4 fields, saw 5
# Skipping line 12480706: expected 4 fields, saw 6
# Skipping line 12493078: expected 4 fields, saw 5
# Skipping line 12493123: expected 4 fields, saw 6
# Skipping line 12493168: expected 4 fields, saw 5
# Skipping line 12493169: expected 4 fields, saw 5
# Skipping line 12493174: expected 4 fields, saw 7
# Skipping line 12493663: expected 4 fields, saw 5
# Skipping line 12493698: expected 4 fields, saw 5
# Skipping line 12493704: expected 4 fields, saw 5
# Skipping line 12515638: expected 4 fields, saw 5
# Skipping line 12515778: expected 4 fields, saw 5
# Skipping line 12521727: expected 4 fields, saw 5
# Skipping line 12522242: expected 4 fields, saw 5
# Skipping line 12522670: expected 4 fields, saw 5
# Skipping line 12536636: expected 4 fields, saw 10
# Skipping line 12537936: expected 4 fields, saw 5
# Skipping line 12537937: expected 4 fields, saw 5
# Skipping line 12539285: expected 4 fields, saw 6
# Skipping line 12539286: expected 4 fields, saw 6
# Skipping line 12539287: expected 4 fields, saw 6
# Skipping line 12551211: expected 4 fields, saw 5
# Skipping line 12551296: expected 4 fields, saw 6
# Skipping line 12569243: expected 4 fields, saw 6
# Skipping line 12569273: expected 4 fields, saw 5
# Skipping line 12569600: expected 4 fields, saw 5
# Skipping line 12569717: expected 4 fields, saw 5
# Skipping line 12570996: expected 4 fields, saw 5
# Skipping line 12570997: expected 4 fields, saw 5
# Skipping line 12571113: expected 4 fields, saw 7
# Skipping line 12571638: expected 4 fields, saw 8
# Skipping line 12571665: expected 4 fields, saw 5
# Skipping line 12571897: expected 4 fields, saw 5
# Skipping line 12581699: expected 4 fields, saw 5
# Skipping line 12584585: expected 4 fields, saw 5
# Skipping line 12587436: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 12593978: expected 4 fields, saw 8
# Skipping line 12596415: expected 4 fields, saw 5
# Skipping line 12601043: expected 4 fields, saw 5
# Skipping line 12606761: expected 4 fields, saw 5
# Skipping line 12616236: expected 4 fields, saw 40
# Skipping line 12621410: expected 4 fields, saw 5
# Skipping line 12622341: expected 4 fields, saw 5
# Skipping line 12622425: expected 4 fields, saw 5
# Skipping line 12622618: expected 4 fields, saw 5
# Skipping line 12653670: expected 4 fields, saw 5
# Skipping line 12654975: expected 4 fields, saw 5
# Skipping line 12654976: expected 4 fields, saw 5
# Skipping line 12654977: expected 4 fields, saw 5
# Skipping line 12657512: expected 4 fields, saw 5
# Skipping line 12657514: expected 4 fields, saw 7
# Skipping line 12657548: expected 4 fields, saw 5
# Skipping line 12657633: expected 4 fields, saw 5
# Skipping line 12657634: expected 4 fields, saw 5
# Skipping line 12657635: expected 4 fields, saw 5
# Skipping line 12657684: expected 4 fields, saw 5
# Skipping line 12657764: expected 4 fields, saw 5
# Skipping line 12678776: expected 4 fields, saw 5
# Skipping line 12680130: expected 4 fields, saw 6
# Skipping line 12683940: expected 4 fields, saw 5
# Skipping line 12683999: expected 4 fields, saw 5
# Skipping line 12684002: expected 4 fields, saw 5
# Skipping line 12684009: expected 4 fields, saw 6
# Skipping line 12684011: expected 4 fields, saw 5
# Skipping line 12684012: expected 4 fields, saw 5
# Skipping line 12684017: expected 4 fields, saw 7
# Skipping line 12684020: expected 4 fields, saw 7
# Skipping line 12684023: expected 4 fields, saw 5
# Skipping line 12741181: expected 4 fields, saw 5
# Skipping line 12741189: expected 4 fields, saw 5
# Skipping line 12741190: expected 4 fields, saw 5
# Skipping line 12741199: expected 4 fields, saw 5
# Skipping line 12741410: expected 4 fields, saw 7
# Skipping line 12741411: expected 4 fields, saw 6
# Skipping line 12741412: expected 4 fields, saw 6
# Skipping line 12741413: expected 4 fields, saw 6
# Skipping line 12741414: expected 4 fields, saw 7
# Skipping line 12741415: expected 4 fields, saw 8
# Skipping line 12741416: expected 4 fields, saw 6
# Skipping line 12741417: expected 4 fields, saw 7
# Skipping line 12741418: expected 4 fields, saw 6
# Skipping line 12741419: expected 4 fields, saw 7
# Skipping line 12741420: expected 4 fields, saw 6
# Skipping line 12741421: expected 4 fields, saw 6
# Skipping line 12741422: expected 4 fields, saw 9
# Skipping line 12741423: expected 4 fields, saw 6
# Skipping line 12741424: expected 4 fields, saw 6
# Skipping line 12741847: expected 4 fields, saw 5
# Skipping line 12741873: expected 4 fields, saw 7
# Skipping line 12748886: expected 4 fields, saw 5
# Skipping line 12748887: expected 4 fields, saw 5
# Skipping line 12755852: expected 4 fields, saw 5
# Skipping line 12756019: expected 4 fields, saw 5
# Skipping line 12756020: expected 4 fields, saw 5
# Skipping line 12756021: expected 4 fields, saw 6
# Skipping line 12756022: expected 4 fields, saw 8
# Skipping line 12756023: expected 4 fields, saw 7
# Skipping line 12756189: expected 4 fields, saw 6
# Skipping line 12756190: expected 4 fields, saw 6
# Skipping line 12756218: expected 4 fields, saw 5
# Skipping line 12761154: expected 4 fields, saw 5
# Skipping line 12761155: expected 4 fields, saw 5
# Skipping line 12761156: expected 4 fields, saw 5
# Skipping line 12761157: expected 4 fields, saw 5
# Skipping line 12762607: expected 4 fields, saw 5
# Skipping line 12764795: expected 4 fields, saw 5
# Skipping line 12764799: expected 4 fields, saw 5
# Skipping line 12764808: expected 4 fields, saw 5
# Skipping line 12764843: expected 4 fields, saw 5
# Skipping line 12764886: expected 4 fields, saw 5
# Skipping line 12764890: expected 4 fields, saw 5
# Skipping line 12767566: expected 4 fields, saw 5
# Skipping line 12772488: expected 4 fields, saw 5
# Skipping line 12772539: expected 4 fields, saw 5
# Skipping line 12775420: expected 4 fields, saw 5
# Skipping line 12794935: expected 4 fields, saw 5
# Skipping line 12795584: expected 4 fields, saw 5
# Skipping line 12819860: expected 4 fields, saw 5
# Skipping line 12853547: expected 4 fields, saw 9
# Skipping line 12853632: expected 4 fields, saw 5
# Skipping line 12853633: expected 4 fields, saw 6
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
# <ipython-input-8-cbcff298eeff>:13: ParserWarning: Skipping line 12860377: expected 4 fields, saw 6
# Skipping line 12878092: expected 4 fields, saw 5
# Skipping line 12883306: expected 4 fields, saw 5
# Skipping line 12891168: expected 4 fields, saw 6
# Skipping line 12896131: expected 4 fields, saw 5
# Skipping line 12896132: expected 4 fields, saw 5
# Skipping line 12896133: expected 4 fields, saw 5
#
#   df = pd.read_csv(output_csv_path, quotechar='"',escapechar='\\', keep_default_na=True, on_bad_lines='warn')
#                             user_id                      "artistname"  \
# 0  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2  9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
#
#                                          "trackname"  "playlistname"
# 0               (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1  (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                   7 Years Too Late  HARD ROCK 2010
# 3                              Accidents Will Happen  HARD ROCK 2010
# 4                                             Alison  HARD ROCK 2010

# %% [markdown]
# How many rows in the malformed rows, have less than 4 elements : (answer is 0)

# %%
# Define the file path
file_path = 'spotify_dataset.csv'  # Update with your actual file path

# Open the file and check for malformed rows
malformed_rows = []
with open(file_path, 'r') as file:
    for i, line in enumerate(file):
        # Split the row by the delimiter and count elements
        if len(line.split(',')) < 4:  # Adjust '4' to the expected number of columns
            malformed_rows.append((i + 1, line))  # Store the line number and content

# Display malformed rows
print(f"Number of malformed rows: {len(malformed_rows)}")
for line_number, content in malformed_rows[:10]:  # Show the first 10 malformed rows
    print(f"Line {line_number}: {content}")
# Out:
# Number of malformed rows: 0

# %%
# Display basic information
df_original.info()

# Show the first few rows
df_original.head()

# Check for missing values
df_original.isnull().sum()

# Analyze unique values in columns
df_original.nunique()

# Describe the dataset
df_original.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12891680 entries, 0 to 12891679
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   user_id          object
#  1    "artistname"    object
#  2    "trackname"     object
#  3    "playlistname"  object
# dtypes: object(4)
# memory usage: 393.4+ MB
#                                  user_id  "artistname"  "trackname"  \
# count                           12891680      12858108     12891592
# unique                             15918        289820      2032043
# top     4398de6902abde3351347b048fcdc287     Daft Punk        Intro
# freq                              295275         36086         6676
#
#         "playlistname"
# count         12890434
# unique          157504
# top            Starred
# freq           1337085

# %%
# Display basic information
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12891680 entries, 0 to 12891679
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   user_id          object
#  1    "artistname"    object
#  2    "trackname"     object
#  3    "playlistname"  object
# dtypes: object(4)
# memory usage: 393.4+ MB

# %% [markdown]
# dataset has successfully loaded with 12,891,680 rows and 4 columns, but the column names have extra quotes (e.g., "artistname", "trackname", "playlistname"), which might cause issues during analysis.

# %%
df.columns = df.columns.str.strip().str.replace('"', '')
print(df.columns)
# Out:
# Index(['user_id', 'artistname', 'trackname', 'playlistname'], dtype='object')

# %%
# Show the first few rows
df_original.head()
# Out:
#                             user_id                      "artistname"  \
# 0  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2  9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
#
#                                          "trackname"  "playlistname"
# 0               (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1  (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                   7 Years Too Late  HARD ROCK 2010
# 3                              Accidents Will Happen  HARD ROCK 2010
# 4                                             Alison  HARD ROCK 2010

# %%
# Check for missing values
df_original.isnull().sum()
# Out:
# user_id                0
#  "artistname"      33572
#  "trackname"          88
#  "playlistname"     1246
# dtype: int64

# %%
# Analyze unique values in columns
df_original.nunique()
# Out:
# user_id              15918
#  "artistname"       289820
#  "trackname"       2032043
#  "playlistname"     157504
# dtype: int64

# %%
# Describe the dataset
df_original.describe(include='all')
# Out:
#                                  user_id  "artistname"  "trackname"  \
# count                           12891680      12858108     12891592
# unique                             15918        289820      2032043
# top     4398de6902abde3351347b048fcdc287     Daft Punk        Intro
# freq                              295275         36086         6676
#
#         "playlistname"
# count         12890434
# unique          157504
# top            Starred
# freq           1337085

# %%
print(df[df['"artistname"'].str.contains(r'\\', na=False)])  # Rows with backslash in artistname
print(df[df['"trackname"'].str.contains(r'\\', na=False)])  # Rows with backslash in trackname
print(df[df['"playlistname"'].str.contains(r'\\', na=False)])  # Rows with backslash in playlistname
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '"artistname"'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-7a85c997fbd5> in <cell line: 1>()
# ----> 1 print(df[df['"artistname"'].str.contains(r'\\', na=False)])  # Rows with backslash in artistname
#       2 print(df[df['"trackname"'].str.contains(r'\\', na=False)])  # Rows with backslash in trackname
#       3 print(df[df['"playlistname"'].str.contains(r'\\', na=False)])  # Rows with backslash in playlistname
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '"artistname"'

# %% [markdown]
# #EDA- extensive - i need to devide into blocks for better understanding but it is based on all knowledge i got from initial EDA i did.

# %%
import pandas as pd

# Step 1: Load the CSV with `quotechar='"'`
df_original = pd.read_csv('spotify_dataset.csv', quotechar='"', on_bad_lines='skip')
df_original.to_csv('step1_loaded.csv', index=False)
print("Step 1 saved: step1_loaded.csv")

# Step 2: Clean column names
df_original.columns = df_original.columns.str.strip().str.replace('"', '')  # Remove quotes and spaces
df_original.to_csv('step2_cleaned_columns.csv', index=False)
print("Step 2 saved: step2_cleaned_columns.csv")

# Step 3: Handle missing values
df_original = df_original.dropna()  # Remove rows with missing values
# Optional: Fill missing values instead of dropping them
# df_original.fillna({'artistname': 'unknown', 'trackname': 'unknown', 'playlistname': 'unknown'}, inplace=True)
df_original.to_csv('step3_handled_missing.csv', index=False)
print("Step 3 saved: step3_handled_missing.csv")

# Step 4: Convert all string columns to lowercase
string_columns = df_original.select_dtypes(include='object').columns  # Identify string columns
df_original[string_columns] = df_original[string_columns].apply(lambda col: col.str.lower())
df_original.to_csv('step4_lowercase.csv', index=False)
print("Step 4 saved: step4_lowercase.csv")

# Step 5: Duplicate Rows
print(f"Number of duplicate rows: {df_original.duplicated().sum()}")
df_original = df_original.drop_duplicates()
df_original.to_csv('step5_removed_duplicates.csv', index=False)
print("Step 5 saved: step5_removed_duplicates.csv")

# Step 6: Distribution Analysis
print(df_original['artistname'].value_counts().head(10)) # Most Frequent Artists

print(df_original['trackname'].value_counts().head(10)) # Most Frequent Tracks

#Save these distributions for review:
df_original['artistname'].value_counts().head(10).to_csv('top10_artists.csv')
df_original['trackname'].value_counts().head(10).to_csv('top10_tracks.csv')

# Step 7: Playlist Diversity
playlist_diversity = df_original.groupby('playlistname')['trackname'].nunique()
playlist_diversity.to_csv('step7_playlist_diversity.csv')
print("Step 7 saved: step7_playlist_diversity.csv")

df_original['artistname'] = df_original['artistname'].str.strip()
df_original['trackname'] = df_original['trackname'].str.strip()
df_original['playlistname'] = df_original['playlistname'].str.strip()

# Step 8: Normalize or Standardize Text
#Remove extra spaces, special characters, or unusual formatting in text fields
df_original.to_csv('step8_normalized_text.csv', index=False)
print("Step 8 saved: step8_normalized_text.csv")

# Step 9: Check for Unusual Values
print(df_original[df_original['artistname'].str.len() < 2])  # Artists with very short names
print(df_original[df_original['trackname'].str.len() < 2])  # Tracks with very short names
print(df_original[df_original['playlistname'].str.len() < 2])  # Playlists with very short names

# filter these values out:
df_original = df_original[df_original['artistname'].str.len() >= 2]
df_original = df_original[df_original['trackname'].str.len() >= 2]
df_original = df_original[df_original['playlistname'].str.len() >= 2]

df_original.to_csv('step9_filtered_unusual_values.csv', index=False)
print("Step 9 saved: step9_filtered_unusual_values.csv")

# Step 10: Create Summary Statistics
summary = df_original.describe(include='all')
summary.to_csv('step10_summary_statistics.csv')
print("Step 10 saved: step10_summary_statistics.csv")

# Step 11:Identify Relationships
#Track Count per Artist
track_count_per_artist = df_original.groupby('artistname')['trackname'].nunique()
track_count_per_artist.to_csv('step11_track_count_per_artist.csv')
print("Step 11 saved: step11_track_count_per_artist.csv")

#Tracks per Playlist
tracks_per_playlist = df_original.groupby('playlistname')['trackname'].nunique()
tracks_per_playlist.to_csv('step11_tracks_per_playlist.csv')
print("Step 11 saved: step11_tracks_per_playlist.csv")

# Step 12: Save Cleaned and Processed Data
#Save Cleaned and Processed Data
df_original.to_csv('final_cleaned_dataset.csv', index=False)
print("Final dataset saved: final_cleaned_dataset.csv")
# Out:
# Step 1 saved: step1_loaded.csv
# Step 2 saved: step2_cleaned_columns.csv
# Step 3 saved: step3_handled_missing.csv
# Step 4 saved: step4_lowercase.csv
# Number of duplicate rows: 25183
# Step 5 saved: step5_removed_duplicates.csv
# artistname
# daft punk             36049
# coldplay              35521
# radiohead             31454
# the rolling stones    30746
# kanye west            29112
# jay z                 28966
# eminem                28896
# queen                 28010
# david bowie           27790
# michael jackson       26224
# Name: count, dtype: int64
# trackname
# intro          6712
# home           5607
# closer         3551
# runaway        3350
# hold on        3282
# radioactive    3188
# forever        3067
# stay           3006
# alive          2940
# wake me up     2838
# Name: count, dtype: int64
# Step 7 saved: step7_playlist_diversity.csv
# Step 8 saved: step8_normalized_text.csv
#                                    user_id artistname  \
# 14137     650c4d63a819dbb77cc15a87f407039a
# 45135     db937456654d2465292c4daa947c95de          m
# 49622     db937456654d2465292c4daa947c95de          t
# 52017     db937456654d2465292c4daa947c95de          m
# 77535     6cdb890a9fff57be31b072777350e632          x
# ...                                    ...        ...
# 12853894  675687eafb4c14f1ea561e6089ee2ec0          x
# 12854130  675687eafb4c14f1ea561e6089ee2ec0          x
# 12854301  675687eafb4c14f1ea561e6089ee2ec0          x
# 12854813  675687eafb4c14f1ea561e6089ee2ec0          x
# 12855542  675687eafb4c14f1ea561e6089ee2ec0          x
#
#                                           trackname           playlistname
# 14137                            central park blues              overboard
# 45135         3ox feat. heidrun-beating of my heart                 strane
# 49622                             rex-christmas bop                 strane
# 52017         3ox feat. heidrun-beating of my heart                trening
# 77535                               the hungry wolf  perfect records edits
# ...                                             ...                    ...
# 12853894              sex and dying in high society                starred
# 12854130                               soul kitchen                starred
# 12854301                                 sugarlight                starred
# 12854813        the world's a mess; it's in my kiss                starred
# 12855542  your phone's off the hook, but you're not                starred
#
# [1617 rows x 4 columns]
#                                    user_id            artistname trackname  \
# 3102      c50566d83fba17b20697039d5824db78             athletics         i
# 3218      c50566d83fba17b20697039d5824db78             athletics         v
# 3394      c50566d83fba17b20697039d5824db78  three trapped tigers         6
# 5874      c50566d83fba17b20697039d5824db78            air review         h
# 6281      c50566d83fba17b20697039d5824db78             athletics         i
# ...                                    ...                   ...       ...
# 12885184  aedf684d88f71c448add86ee4873278e         mitch hedberg         x
# 12887558  8e430be89a7c972611c503bb23fbc3f7                 barem         a
# 12887972  8e430be89a7c972611c503bb23fbc3f7            föllakzoid         9
# 12889559  8d27d5741b3210e41ab3a499c1141af9          zodiak killa         6
# 12891348  488ead471813ae982119153f792e4a3e          yoga pop ups         3
#
#                               playlistname
# 3102                         december 2013
# 3218                         december 2013
# 3394                    everything at once
# 5874                    everything at once
# 6281                    everything at once
# ...                                    ...
# 12885184                            comedy
# 12887558  2011- albums i have to listen to
# 12887972       cd's & vinyls february 2013
# 12889559              mis pistas de shazam
# 12891348                       yoga pop up
#
# [4742 rows x 4 columns]
#                                    user_id    artistname  \
# 52892     706c53ae3e25cf5c9f13caa871f7de91      maroon 5
# 52893     706c53ae3e25cf5c9f13caa871f7de91      maroon 5
# 52894     706c53ae3e25cf5c9f13caa871f7de91      maroon 5
# 52895     706c53ae3e25cf5c9f13caa871f7de91      maroon 5
# 52896     706c53ae3e25cf5c9f13caa871f7de91      maroon 5
# ...                                    ...           ...
# 12868241  6710bd50ccdbb3c5308adea240695e6a         dusky
# 12868242  6710bd50ccdbb3c5308adea240695e6a    disclosure
# 12868243  6710bd50ccdbb3c5308adea240695e6a   alunageorge
# 12868244  6710bd50ccdbb3c5308adea240695e6a     eli & fur
# 12868245  6710bd50ccdbb3c5308adea240695e6a  fenech-soler
#
#                                     trackname playlistname
# 52892                                 animals            v
# 52893                     coming back for you            v
# 52894                                feelings            v
# 52895                          in your pocket            v
# 52896                       it was always you            v
# ...                                       ...          ...
# 12868241                               yoohoo            5
# 12868242               you & me - flume remix            5
# 12868243  you know you like it - bondax remix            5
# 12868244                       you're so high            5
# 12868245                                youth            5
#
# [41277 rows x 4 columns]
# Step 9 saved: step9_filtered_unusual_values.csv
# Step 10 saved: step10_summary_statistics.csv
# Step 11 saved: step11_track_count_per_artist.csv
# Step 11 saved: step11_tracks_per_playlist.csv
# Final dataset saved: final_cleaned_dataset.csv

# %%
import pandas as pd

# Load the final saved file
df_final = pd.read_csv('final_cleaned_dataset.csv')

# 1. Basic Information
print("Basic Information:")
print(df_final.info())

# 2. Shape of the Dataset
print("\nShape of the Dataset:")
print(f"Number of rows: {df_final.shape[0]}")
print(f"Number of columns: {df_final.shape[1]}")

# 3. Summary Statistics
print("\nSummary Statistics:")
print(df_final.describe(include='all'))  # Include all columns (numeric and categorical)

# 4. Column-Wise Null Check
print("\nMissing Values Per Column:")
print(df_final.isnull().sum())

# 5. Head and Tail (First and Last Rows)
print("\nFirst 5 Rows:")
print(df_final.head())

print("\nLast 5 Rows:")
print(df_final.tail())
